# %%
# 
"""
21 Jump Street by Dhanush Teja

    DocString:
    
    A) Introduction:
    Welcome to 21 Jump Street, Jenko and Schmidt have just been dopped off the force becasue they messed up,
    they only get a second chance because they look young, they have been pushed to the Jump Street divison
    Where Captin Dickson has briefed you about going back to school, this time its not for studies, its to 
    stop the supply of drugs.
  
    Game flow:
    
    Level 1: Get into School and don't get kicked out
    Level 2: Throwing a House Party
    Level 3: Infiltrate the dealer and find the suppliers 
    Level 4: Raid the dealer and suppliers meeting
    Final level : Final, so close yet so far
    
    B) Known Bugs and/or Errors:
    None.
    
"""

## Importing necessary packages
import sys

#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Scroll all the way to the bottom to view main function
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$


#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Level 1- Get into School and don't get kicked out
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$


def stage1():
# Introducing the scene in school
    print(f"""{45*"*"}Level 1{44*"*"}\n""")
    print("2 guys Schmidt & Jenko go to school to gather intel. one goes to science one goes to arts")  
    print("""
   Class A - arts
   Class B - science subjects""")
    print("\n")
    print("""
    To get access into the classes without getting caught you need to answer a question 
    .\n""")
    
# To validate if player is showing the correct input  
# Input value should be numeric and should also be in [1,2,3,4]
    stage1_options=[1,2,3,4]
    conditions = False
# Loop until user provides the right input format       
    while conditions == False:
        try:
# Questions to put player to the test            
            school_access = input(prompt= """
            Which famous movie star had a starring role in "21 Jump Street"?
            (this person had also recently been on trail)
            1.Matt Damon
            2.Leonardo Di Caprio
            3.Johnny Depp
            4.Tom Hanks\n>> """) 
# In order to validate the supplied input, input is converted to integer.   
            school_access = int(school_access)
            if school_access in stage1_options:
                conditions = True  
# If the value provided is not in the sta1 the following message will be displayed                
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3 or 4)")
# If the value provided is not an interger the following message will be displayed              
        except:
            print("Please provide a numeric value.\n")      

# Checking to see whether the provided input is correct.           
    if school_access == 3:
            
        print("""
        You are right! Johnny Depp does star in this movie.
        Wasnt he amazing?
        """)
# Calling Stage 2 function- Party
        print("\n")
        stage2()  

       
    else:
        end_game()
    
    return ()# Brings me back to the main function


#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Level 2- Throwing a House party
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$


def stage2():
# Briefing about the game flow  
    #print(f"""{45*"*"}Level 2{44*"*"}\n""")   
    
    print("""
    In this stage, You decide to throw a party and invite people from both the classes
    
    """)  
    
    print("""
    You have to use this opportunity to find the dealer and add a tracker to his phone, Jenko has the 
    duty of taking the phone while Schmidt is dealing with distraction
    \n""")   
    input('<Press any key to proceed>\n')
    stage3()

# Control returns back to the calling program which is the stage1

#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# level 2- Infiltrate the dealer and find the suppliers
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$


def stage3():
   
    print(f"""{43*"*"}Level 2- Infiltrate the dealer and find the suppliers{41*"*"}\n""")  
    print("""
    All your friends have arrived here including the dealer. schmidt will have to 
    create a distraction, so jenko could get the phone
    """)
    
# To Create Distraction------------------------------------------------   
    print(f"""{44*"-"}Task 1{44*"-"}\n""") 
    print("""In order to begin your journy, you need to answer a question.\n""")
# Question to begin hunt    
    riddle = int(input(prompt = """The headquarters of the Jump Street squad was in a
    building. Which of the following buildings housed their headquarters? 
    
    1. a dance hall
    2. a high school
    3. an abandoned chapel
    4. an old movie theatre

    """) ) 
    print("\n")
    
# Validating user input in the list value    
    if riddle == 3:
        print(""""
        You are right! You have succesfully created a distraction
        """)
    else:
        print("Sorry incorrect answer, you will not be able to proceed.")  
        print("The right answer is 3.")  
        end_game()
# To print space        
    print("\n")

    
# stealing the phone-------------------------------------------------------------   

    print(f"""{42*"-"}Task 2{37*"-"}\n""")    
    print("""
    You now need to take the phone from the dealer. Answer the questions right
    """)
    
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3,4]

    round1_option = [1,2,3,4]
    correct_value = False
# Loop until user provides the right input format    
    while correct_value == False:
        try:            
# Question to choose weapon     
            task1_ans_g = input(prompt= """
    Why did the squad shift to Jump Street?
    1. They were really bad at thier job
    2. Jenko had a child on the way
    3. Jenko couldnt run properly
    4. Schmidt had an affair with the captins daughter
 """)  
# Converting input to integer in order to validate the provided input     
            task1_ans_g = int(task1_ans_g)

# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3,4]
            if (task1_ans_g in round1_option):  
                correct_value = True 
# If the value provided is not in the round1_option the following message will be displayed  
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3 or 4)")              
# If the value provided is not an interger the following message will be displayed 
        except:
            print("Please provide a numeric value.")  
            
# Verifying if the given input is the right answer 
    print("\n")
    if (task1_ans_g == 1): 
        print("""You are right! You have chosen the right answer. you have
        successfully stolen the phone and placed a tracker""")
    else:
        print("""Sorry incorrect answer, You will not be able to proceed to steal the phone.""")
        print("The right answer is option ''.")
        end_game()
    print("\n")

    
# Put the phone back---------------------------------------------------------- 

    print(f"""{45*"-"}Task 3t
    {44*"-"}\n""")             
    print("""WARNING the dealer is leaving where should Jenko put the phone without
    getting caught.""")
# defining options
    
    correct1_value = False
# Loop until user provides the right input format    
    while correct1_value == False:
        try:              
# Question to drop the phone back     
            drop_phone = input(prompt= """
    Where are you going to put the phone?
    1. On the table
    2. In the Dealers car
    3. Give the phone to Schmidt
    4. In the dealers pocket\n>> """)
# Converting input to integer in order to validate the provided input     
            drop_phone = int(drop_phone)

# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3,4]
            if (drop_phone in round1_option):  
                correct1_value = True 
# If the value provided is not in the round1_option the following message will be displayed  
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3 or 4)")              
# If the value provided is not an interger the following message will be displayed 
        except:
            print("Please provide a numeric value.")  
            
# Verifying if the given input is the right answer 
    print("\n")
    if (drop_phone == 4): 
        print("""You are right! You have chosen the right option. The phone
        was successfully placed back in his pocket""")
        stage4()
    else:
        print("""Sorry incorrect answer, You were not able to find the right place to keep the phone.""")
        print("The right answer is option '4. In the dealers pocket'.")        
    print("\n")
    end_game()


# Printing space    
    print("\n")    

#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Level 3- Raid the dealer and suppliers meeting
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

def stage4():
   
    print(f"""{45*"*"}Level 3 -{44*"*"}\n""")    
    print("")
    print(""""Congratulations, You have succesfully placed the tracker, with the available 
    inte you have track the dealer to his next meeting with the supplier,
    to successfully raid, answer the following question""")
    print("\n")
    print("Kindly input as 't' or 'f'. ")
        
# Allowing 2 chances for reward task in case of incorrect answer
    chances = 2
    while chances >= 1: 
# Initializing a value to see if the user is using the right input format.( 't' or 'f') 

        tf1=['t' , 'f']        
        correct_value = False
# Loop until user provides the right input format         
        while correct_value == False:
# True/False questions             
            wand_task = input(prompt= "1. Jenko and Schmidt wear black Tuxedos for prom (true/false):t/f\n>> ")                          
#To validate if user is providing the correct input format 
            if (wand_task in tf1):  
                correct_value = True 
# If the value provided is not in the t,f the following message will be displayed             
            else:
                print("Please provide a correct value.(e.g., 't' or 'f')")               
# Validating reward challenge answer
        if (wand_task == 'f'): 
            print("""
            Success. You have raided the place and you find both along with the drugs""")
            print("\n")
# Calling the Final function            
            Final()
        else: 
# All chances have been used up, but still the player did not provide the right answer             
            if chances == 1:
                print("""
                Sorry you lost the chance to raid, 
                and the chances of saving your jobs with it.
                """)
                print("The right answer is 'f'")            
            
                end_game()
                  #will exit the loop and proceed to the end game program
                      
            else:    
# Asking player if they would like to try another time                
                user_option = input(prompt="""
                 
                would you like to retry once more?:y/n
                """)
# If 'yes' loop once more else exit and call end_game function
                if user_option == 'y':
                    chances = chances - 1
                    continue # will continue looping
                else:
                    print("The right answer is 't'")                      
                    end_game() 
                    # will exit the loop and proceed to the end game program            
                        
        
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Final, so close yet so far
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
def Final():
    
    print(f"""{43*">"}Final Stage- so close yest so far{41*"<"}\n""")    
    print("You are now stuck in a problem/n ")
    print("""
    You have to answer Both questions carefully.
    This will be your decsion to stop the Drug trade.
    
    """)

     
# Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]

    final = [1,2,3]
    correct_value = False
# Loop until user provides the right input format     
    while correct_value == False:
        try:
# Questions for the final round   
            final_Q1 = input(prompt= """
            which would you Seize?  
            1.Dealer 
            2.Supplier
            3.Dealer and Drugs\n>> """) 
            final_Q2 = input(prompt= """
            Who is the Supplier?
            1. Doug Mcquade
            2. Eric Moison
            3. Walters\n>> """) 
           # In order to validate the supplied input, input is converted to integer.   
            final_Q1 = int(final_Q1)
            final_Q2 = int(final_Q2)
             

# Recognize that adding a while loop to each question will improve the user experience 
# However, adding while loops to check each question will complicate the code.


            if (final_Q1 in final) and (final_Q2 in final):  
                correct_value = True 
# If the specified value is not in the lst1, the message below will be shown.             
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")     
# If the value provided is not an interger then message below will be displayed            
        except:
            print("Please provide a numeric value.")             

# Verrifying the user input     
    if (final_Q1 == 2 and final_Q2 == 3):
        print("""
        Congratulations... The Supplier has been arrested. you have prevented the
    spread of drugs across the city.""")
        print(""" 
        
                                                                                        
        THANK YOU FOR PLAYING THE 21 JUMP STREET- DT EDITION TEXT BASED GAME
                                                                                          """)
    else:    
        
        print(f"""/n/n
        The right answers are:-
        Q1: 2. Supplier,
        Q2: 3. Walters """) 
    end_game()# exiting the game 


    

#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Starting of the game
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# The remaining functions (different phases) are derived from this primary function.
def start_game():
    # Multiplying * into 2 times to print as follows *********-------------------
    print(f"""{2*"*"}\n""")

# 21 Jump Street - DT Edition game title  header----------------------------------
    print(" 21 Jump Street - DT Edition\n")

# Multiplying * into 2 times to print as follows *********-------------------
    print(f"""{2*"*"}\n""")

    print("""
You are two cops who just graduated out of a police acdemy,You are assigned a
big drug bust case""")  
    print("""You and your partner are responsible for solving this,
    make sure you carefully answer,one wrong decsion could make you lose.\n""")
    

# Calling Stage 1 function- for colour discussion--------------------------   
    stage1()           
    


     
# Calling the final function------------------------------------------------
    print("\n")
    Final()

# Fail function
def end_game():
    # Initializing value to validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
    end_choices=[1,2,3]   
    Numerical = False
    while Numerical == False:
        try:            
            player_feeling = input(prompt= """
            Damn.. You almost had it. How was the experience :
            1. Amazing game.
            2. It was alright.
            3. Good experience\n>> """) 
            player_feeling = int(player_feeling)

# To validate if user is providing the correct input format 
# Input value to be numeric and should be in [1,2,3]
            if player_feeling in end_choices:
                Numerical = True    
            else:
                print("Please provide a correct value.(e.g., 1 or 2 or 3)")
        except:
            print("Please provide a numeric value.")      
    
    if player_feeling == 2:
        print("""
        I shall work to make it better. 
        """)
    else:
        print("Amazing job, hope you had fun.")
        print("\n")
        
    print("Thanks for playing!\n")
    Input = False
    while Input == False:    
        play_again = input(prompt= "Come on lets play again? y/n\n>> ")
        if (play_again == 'y'):
            Input = True
            stage1()
        elif (play_again == 'n'):  
            Input = True            
            sys.exit()           
        else:
            print("Invalid Input")

#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Calling start game function to get started
start_game()
# Out:
# **
#
#  21 Jump Street - DT Edition
#
# **
#
#
# You are two cops who just graduated out of a police acdemy,You are assigned a
# big drug bust case
# You and your partner are responsible for solving this,
#     make sure you carefully answer,one wrong decsion could make you lose.
#
# *********************************************Level 1********************************************
#
# 2 guys Schmidt & Jenko go to school to gather intel. one goes to science one goes to arts
#
#    Class A - arts
#    Class B - science subjects
#
#
#
#     To get access into the classes without getting caught you need to answer a question
#     .
#
#
#             Which famous movie star had a starring role in "21 Jump Street"?
#             (this person had also recently been on trail)
#             1.Matt Damon
#             2.Leonardo Di Caprio
#             3.Johnny Depp
#             4.Tom Hanks
# >> 3
#
#         You are right! Johnny Depp does star in this movie.
#         Wasnt he amazing?
#
#
#
# ...
